# %% [markdown]
#  **Financial (K stock price) trading rules using Machine Learning**
#
#  Version 1.6.2.
#
# Jojothepizza/ jo-cho

# %% [markdown]
# 1. Financial Data and Bars
#  - OHLCV Bar
#  - summary and plot
#
# 2. Trend Signals (Long only)
#  - TAs (sma, fi, rsi)
#  - Combined with CUSUM Filter
#
# 3. Labeling
#  - Binary Label (Triple Barrier - trading rule)
#  - Meta-Labeling (Profit or Loss (use for prediction)
#
# 4. Prediction of whether bet or not
#
#  4.1. Features (X)
#  - Technical Indicators
#  - Feature Scaling (MinMaxScaler)
#  - Feature Selection (PCA/ (Autoencoder))
#
#  4.2. Prediction
#  - Cross Validation (Purged K-Fold)/ Simple Split
#  - RF / LSTM
#  - Metrics (Accuracy,Recall,Precision,F1-score,Confusion matrix,ROC Curve)
#
# 5. Results
#  - CUM Returns, Sharpe Ratio

# %%
# mlfinlab (BIG THANKS TO DE PRADO and HUSONTHAMES)
import mlfinlab
from mlfinlab import data_structures, features, labeling, util, sampling
from mlfinlab import filters as flt
from mlfinlab import structural_breaks, microstructural_features, cross_validation, feature_importance
from mlfinlab import bet_sizing as bs

# lib
import numpy as np
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

from scipy.stats import norm, moment

#feature
from sklearn import preprocessing
from sklearn.decomposition import PCA 

# CV
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, validation_curve
from sklearn.model_selection import cross_val_score, cross_val_predict

#ML
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

from sklearn.metrics import plot_roc_curve
from sklearn.metrics import roc_curve, confusion_matrix, accuracy_score, classification_report, auc
from sklearn.metrics import plot_confusion_matrix
from sklearn import metrics

#Tensorflow & Keras
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import LSTM
from keras import regularizers
from keras.utils.vis_utils import plot_model

# statistical tests
from statsmodels.graphics.gofplots import qqplot
from statsmodels.tsa.stattools import adfuller
from scipy.stats import shapiro

# technical analysis
import ta

# Pyfolio
import pyfolio as pf

# datareader
import FinanceDataReader as fdr

# %%
import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# # Financial Data and Bars

# %% [markdown]
# ## OHLCV Bar
#
# - Stocks (삼성전자, SK하이닉스, LG화학, 삼성바이오로직스, 현대차)
# - Daily minutes OHLCV(open, high, low, close, volume)

# %%
start_date = dt.datetime(2011,1,1)
end_date = dt.datetime(2021,1,1)

삼성전자 = '005930'
SK하이닉스 = '000660'
LG화학 = '051910'
NAVER = '035420'
현대차 = '005380'

# %%
df1 = fdr.DataReader(삼성전자,start=start_date,end=end_date)
df2 = fdr.DataReader(SK하이닉스,start=start_date, end=end_date)
df3 = fdr.DataReader(LG화학,start=start_date,end=end_date)
df4 = fdr.DataReader(현대차,start=start_date, end=end_date)
df5 = fdr.DataReader(NAVER,start=start_date,end=end_date)

# %%
df1.head()
# Out:
#              Open   High    Low  Close  Volume    Change
# Date
# 2011-01-03  19100  19320  19000  19160  265562  0.009484
# 2011-01-04  19120  19219  18980  19160  274488  0.000000
# 2011-01-05  19100  19100  18840  18840  336224 -0.016701
# 2011-01-06  18840  18980  18460  18600  387488 -0.012739
# 2011-01-07  18300  18580  18280  18420  463447 -0.009677

# %% [markdown]
# ## summary & plots

# %%
df1.describe()
# Out:
#                Open          High           Low         Close        Volume  \
# count   2463.000000   2463.000000   2463.000000   2463.000000  2.463000e+03
# mean   34833.089728  35186.117743  34474.100284  34898.656110  4.273631e+06
# std    12966.037282  13106.671297  12833.340450  12931.574952  8.001779e+06
# min        0.000000      0.000000      0.000000  13600.000000  0.000000e+00
# 25%    25400.000000  25620.000000  25190.000000  25380.000000  2.095760e+05
# 50%    29340.000000  29600.000000  29080.000000  29340.000000  2.944110e+05
# 75%    46390.000000  46800.000000  45955.000000  46300.000000  6.750430e+06
# max    79000.000000  81300.000000  78200.000000  81000.000000  6.349111e+07
#
#             Change
# count  2463.000000
# mean      0.000741
# std       0.017430
# min      -0.080357
# 25%      -0.009685
# 50%       0.000638
# 75%       0.010346
# max       0.104706

# %%
closes = pd.DataFrame({'SamsungElect':df1.Close,'SKHynix':df2.Close,'LGChem':df3.Close,'HyundaiCar':df4.Close,'Naver': df5.Close})

# %%
closes
# Out:
#             SamsungElect  SKHynix  LGChem  HyundaiCar   Naver
# Date
# 2011-01-03         19160    25300  390500      177000   69530
# 2011-01-04         19160    25600  395000      178000   69530
# 2011-01-05         18840    25900  418000      189000   69843
# 2011-01-06         18600    26100  418000      194000   69530
# 2011-01-07         18420    26100  415500      198000   70628
# ...                  ...      ...     ...         ...     ...
# 2020-12-23         73900   116000  806000      185000  284000
# 2020-12-24         77800   118000  818000      187000  282000
# 2020-12-28         78700   115500  814000      189500  281000
# 2020-12-29         78300   116000  813000      190500  283000
# 2020-12-30         81000   118500  824000      192000  292500
#
# [2463 rows x 5 columns]

# %%
plt.figure(figsize=(10,6))
plt.title('Close Prices')
plt.plot(closes)
plt.legend(closes)
plt.show();

# %%
plt.figure(figsize=(10,6))
plt.title('Close Cum Return')
plt.plot(closes.pct_change().cumsum())
plt.legend(closes)
plt.show();

# %% [markdown]
# # Trading Strategy
#
#  ## Only long

# %%
close = df1.Close
close = close.rename('close')

volume = df1.Volume
open = df1.Open
high = df1.High
low = df1.Low

# %%
filters = pd.DataFrame(close)
mt = 1 # 1 day

# %%
# First step: SMA filter
#정배열 = 1, 역배열 = 0

n_f = 10
n_s = 30

sma_f=ta.trend.sma_indicator(close,n_f*mt)
sma_s=ta.trend.sma_indicator(close,n_s*mt)

# %%
filters['sma'] = np.where(sma_f> sma_s, 1, 0)
#filters.sma.loc[sma_f<sma_s] = -1

plt.figure(figsize=(15,9))
plt.scatter(filters.index, filters.close,c= filters.sma,cmap='gray_r',alpha=0.75)

cb = plt.colorbar()
cb.ax.tick_params()
plt.title('SMA Filter')
plt.savefig('smaf.jpg')
plt.show()

# %%
## Second Step Force Index
n=14
fi= ta.volume.ForceIndexIndicator(close,volume,n*mt).force_index()

# %%
filters['force'] = np.where(fi>0, 1, 0)
#filters.force.loc[fi<0] = -1

plt.figure(figsize=(15,9))
plt.scatter(filters.index, filters.close,c= filters.force,cmap='gray_r',alpha=0.75)
cb = plt.colorbar()
cb.ax.tick_params()
plt.title('Force Index Filter')
plt.savefig('fi_f.jpg')
plt.show()

# %%
## Third Step RSI

rsi = ta.momentum.rsi(close,14*mt)

# %%
filters['rsi'] = np.where(rsi>50, 1, 0)
#filters.rsi.loc[rsi<50] = -1

plt.figure(figsize=(15,9))
plt.scatter(filters.index, filters.close,c= filters.rsi, cmap='gray_r',alpha=0.75)
cb = plt.colorbar()
cb.ax.tick_params()
plt.title('RSI Filter')
plt.savefig('rsi_f.jpg')
plt.show()

# %% [markdown]
# ## Combined

# %%
fil_sum = filters.iloc[:,1:].sum(axis=1)

signal_0 = pd.Series(0,index=close.index)
signal_0.loc[fil_sum==3] = 1.0

# %%
signal_0
# Out:
# Date
# 2011-01-03    0
# 2011-01-04    0
# 2011-01-05    0
# 2011-01-06    0
# 2011-01-07    0
#              ..
# 2020-12-23    1
# 2020-12-24    1
# 2020-12-28    1
# 2020-12-29    1
# 2020-12-30    1
# Length: 2463, dtype: int64

# %%
cusum = flt.cusum_filter(close, close.pct_change().rolling(14).std())

plt.figure(figsize=(15,9))
plt.plot(filters.close,label='close')
plt.plot(cusum, close.loc[cusum], 
         marker='x',linestyle = 'None', markersize=10, label = 'buy', alpha=0.4)



plt.title('Symmetric Cusum Filter')
plt.legend()
plt.savefig('cusum.jpg')
plt.show()

# %%
signal = signal_0.loc[cusum]

# %% [markdown]
# or select one filter (ex. FI) to figure out which filter is the best
#
# ```
# signal = filters.filtername
# ```

# %%
plt.figure(figsize=(15,9))
plt.scatter(signal.index, filters.close.loc[signal.index],c= signal,linewidth=0.3,marker='x' ,cmap='gray_r',alpha=0.9)
cb = plt.colorbar()
cb.ax.tick_params()
plt.title('Entries: Signals through all filters')
plt.savefig('entries.jpg')
plt.show()

# %%
signal
# Out:
# 2011-01-21    0
# 2011-01-24    0
# 2011-01-26    0
# 2011-01-28    0
# 2011-01-31    0
#              ..
# 2020-12-09    1
# 2020-12-22    1
# 2020-12-23    1
# 2020-12-24    1
# 2020-12-30    1
# Length: 1022, dtype: int64

# %% [markdown]
# # Labeling

# %%
# Triple-Barrier

rollvol = close.pct_change(14).ewm(30).std() # daily volatility of 100 rolling days

side = signal.loc[signal!=0]
t_events = side.index

pt_sl = [1,1] # 익절 손절 수평 배리어 크기의 비율

target = rollvol
num_days = 90 # 최대 투자 기간

vertical_barrier_times = labeling.add_vertical_barrier(t_events, close, num_days=num_days) 
min_ret = 0.0025 # The minimum target return. (주식거래 수수료(세금)로 설정합니다.)

# %%
events0 = labeling.get_events(close, t_events, pt_sl, target, min_ret, num_threads=4,  vertical_barrier_times = vertical_barrier_times)
bin0 = labeling.get_bins(events0, close)
bin0 = bin0.dropna()
# Out:
# 2021-01-09 16:25:39.610194 100.0% apply_pt_sl_on_t1 done after 0.05 minutes. Remaining 0.0 minutes.

# %%
events = labeling.get_events(close, t_events, pt_sl, target, min_ret, num_threads=4, side_prediction = side, vertical_barrier_times = vertical_barrier_times)
bin = labeling.get_bins(events, close)
# Out:
# 2021-01-09 16:25:43.551665 100.0% apply_pt_sl_on_t1 done after 0.05 minutes. Remaining 0.0 minutes.

# %%
# 실현된 수익률
plt.figure(figsize=(10,6))
plt.title('Return of Primary Model')
plt.bar(bin.index,bin.ret,linewidth=0)
plt.savefig('return_of_1stmodel.jpg')
plt.show();

# %%
first_model = pd.DataFrame()

first_model['y_pred'] = side
first_model['y_true'] = np.sign(bin.side*bin.ret)
first_model = first_model.dropna()

y_pred1 = first_model.y_pred
y_true1 = first_model.y_true

# %%
plt.figure(figsize=(15,9))
plt.scatter(first_model.index, close.loc[first_model.index] ,c= y_true1,cmap='vlag',alpha=0.75)
cb = plt.colorbar()
cb.ax.tick_params()
plt.title('Y True')
plt.show()

# %%
print(classification_report(y_true1, y_pred1))
print("Accuracy = ", accuracy_score(y_true1, y_pred1))

mat = confusion_matrix(y_true1, y_pred1)
plt.figure(figsize=(10,6))
sns.heatmap(mat , cmap=plt.cm.Blues, annot=True)
plt.xlabel('predicted label')
plt.ylabel('true label');
plt.title('Confustion Matrix of 1st Model')
plt.savefig('cm1.jpg')
# Out:
#               precision    recall  f1-score   support
#
#         -1.0       0.00      0.00      0.00       153
#          1.0       0.59      1.00      0.74       223
#
#     accuracy                           0.59       376
#    macro avg       0.30      0.50      0.37       376
# weighted avg       0.35      0.59      0.44       376
#
# Accuracy =  0.5930851063829787

# %%
fpr, tpr, _ = roc_curve(y_true1,y_pred1)
roc_auc = auc(fpr, tpr)
plt.figure(figsize=(10,6))
lw = 2
plt.plot(fpr, tpr, color='darkorange',lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic 1st model')
plt.legend(loc="lower right")
plt.savefig('roc1.jpg')
plt.show()

# %% [markdown]
# ## Meta Labeling

# %%
#y = pd.Series(0,index=first_model.index,name='meta_y')
#y.loc[y_true1==y_pred1]=1
#y

y = bin.bin
y
# Out:
# 2011-04-04    0
# 2011-04-06    0
# 2011-07-11    0
# 2011-09-16    1
# 2011-09-27    1
#              ..
# 2020-12-04    1
# 2020-12-07    1
# 2020-12-09    1
# 2020-12-22    1
# 2020-12-23    1
# Name: bin, Length: 376, dtype: int64

# %%
plt.figure(figsize=(15,9))
plt.scatter(first_model.index, close.loc[first_model.index] ,c= y.dropna(),cmap='gray_r',alpha=0.75)
cb = plt.colorbar()
cb.ax.tick_params()
plt.title('Meta-label: Profit(black) vs Loss(white)')
plt.savefig('metalabel.jpg')
plt.show()

# %% [markdown]
# # Trading

# %% [markdown]
# ## Features

# %% [markdown]
# Features that decides bet size

# %%
# MACD
macd = sma_f - sma_s

# %%
adi = ta.volume.acc_dist_index(high,low,close,volume)
chaikin = ta.volume.chaikin_money_flow(high,low,close,volume,n=20*mt)
atr = ta.volatility.average_true_range(high,low,close,n=14*mt)
mi = ta.trend.mass_index(high,low,n=9*mt,n2=25*mt)
adx = ta.trend.ADXIndicator(high,low,close,n=14*mt).adx()
tsi = ta.momentum.tsi(close,r=25*mt,s=13*mt)
ao = ta.momentum.ao(high,low,s=5*mt,len=34*mt)
wr = ta.momentum.WilliamsRIndicator(high,low,close,14*mt).wr()*-1

# %%
kospi = fdr.DataReader('KS11',start_date,end_date)
dji = fdr.DataReader('DJI',start_date,end_date)
usdkrw = fdr.DataReader('USD/KRW',start_date,end_date)

# %%
r1 = close.pct_change()
r5 = close.pct_change(5)
r10 = close.pct_change(10)
r48 = close.pct_change(48)
r100 = close.pct_change(100)

# %%
raw_X = pd.DataFrame({'macd':macd, 'fi':fi,'rsi':rsi,'wr':wr,
                     'adi':adi,'chaikin':chaikin,'atr':atr,'mi':mi,'adx':adx,'tsi':tsi,'ao':ao,'wr':wr,
                     'r1':r1,'r5':r5,'r10':r10,'r48':r48,'r100':r100,
                     'close':close,'kospi':kospi.Close,'dji':dji.Close,'usdkrw':usdkrw.Close})
#raw_X = raw_X.join(df_others)

# Remove look ahead bias
raw_X = raw_X.shift(1).dropna()
raw_X = raw_X.replace([np.inf, -np.inf], np.nan)

# %%
raw_X
# Out:
#                    macd            fi        rsi         wr           adi  \
# Date
# 2011-06-01  -294.666667  3.189329e+07  52.970548  30.985915 -2.999948e+06
# 2011-06-02  -288.000000  3.517282e+07  55.366340  18.309859 -2.723038e+06
# 2011-06-03  -287.333333  5.701319e+06  47.294223  54.545455 -2.937796e+06
# 2011-06-06  -260.666667  6.015660e+06  47.878761  47.540984 -2.891303e+06
# 2011-06-08  -205.333333  6.832698e+06  48.493935  44.262295 -2.648434e+06
# ...                 ...           ...        ...        ...           ...
# 2020-12-24  3813.333333  4.962148e+09  67.749960  13.636364 -1.090921e+08
# 2020-12-25  3743.333333  2.120202e+10  76.461222  13.888889 -9.013210e+07
# 2020-12-29  3756.666667  2.318529e+10  77.941967  16.470588 -1.091198e+08
# 2020-12-30  3806.666667  1.847581e+10  75.663794  22.222222 -1.015349e+08
# 2020-12-31  4016.666667  2.660264e+10  79.928455   3.225806 -7.653008e+07
#
#              chaikin          atr         mi        adx        tsi  \
# Date
# 2011-06-01 -0.094242   443.837682  24.903382  10.755498  -5.894450
# 2011-06-02 -0.122003   436.420705  24.872772  10.552216  -3.446165
# 2011-06-03 -0.207739   449.533512  24.841238  10.089021  -3.751297
# 2011-06-06 -0.201793   435.995404  24.800480   9.818898  -3.819203
# 2011-06-08 -0.131595   433.424303  24.719256   9.988593  -3.698501
# ...              ...          ...        ...        ...        ...
# 2020-12-24 -0.001009  1416.163952  24.802943  42.223938  37.901265
# 2020-12-25 -0.001111  1665.009384  25.156213  43.545632  40.558336
# 2020-12-29 -0.051671  1710.365856  25.419777  45.042403  43.202505
# 2020-12-30  0.049611  1702.482581  25.390145  45.646930  44.552585
# 2020-12-31  0.090842  1866.590968  25.477680  46.743067  47.303571
#
#                      ao        r1        r5       r10       r48      r100  \
# Date
# 2011-06-01  -283.161765  0.020362  0.042775  0.013483  0.030857 -0.058455
# 2011-06-02  -143.455882  0.009978  0.064252  0.020157  0.043528 -0.049061
# 2011-06-03   -78.279412 -0.030735  0.004551  0.003409  0.003409 -0.062633
# 2011-06-06   -71.279412  0.002265 -0.006734  0.003401 -0.027473 -0.048387
# 2011-06-08   -90.514706  0.002260  0.003394  0.016037 -0.031659 -0.036916
# ...                 ...       ...       ...       ...       ...       ...
# 2020-12-24  4645.588235  0.022130  0.001355  0.000000  0.242017  0.252542
# 2020-12-25  4819.117647  0.052774  0.061392  0.067215  0.296667  0.318644
# 2020-12-29  5430.588235  0.011568  0.078082  0.072207  0.292282  0.359240
# 2020-12-30  5978.235294 -0.005083  0.072603  0.060976  0.285714  0.378521
# 2020-12-31  6767.058824  0.034483  0.120332  0.097561  0.347754  0.413613
#
#               close    kospi       dji   usdkrw
# Date
# 2011-06-01  18040.0  2142.47  12569.79  1078.50
# 2011-06-02  18220.0  2141.34  12290.14  1078.35
# 2011-06-03  17660.0  2114.20  12248.55  1081.25
# 2011-06-06  17700.0  2113.47  12151.26  1077.50
# 2011-06-08  17740.0  2099.71  12070.81  1077.40
# ...             ...      ...       ...      ...
# 2020-12-24  73900.0  2759.82  30129.83  1106.65
# 2020-12-25  77800.0  2806.86  30199.87  1101.59
# 2020-12-29  78700.0  2808.60  30403.97  1095.60
# 2020-12-30  78300.0  2820.51  30335.67  1090.97
# 2020-12-31  81000.0  2873.47  30409.56  1087.62
#
# [2271 rows x 20 columns]

# %% [markdown]
# ## Feature Scaling
#
#
# minmax

# %%
scaler = preprocessing.MinMaxScaler((0,1))
scaler.fit(raw_X)
raw_X_scaled = scaler.transform(raw_X)

scaled_X = pd.DataFrame(raw_X_scaled,index=raw_X.index,columns=raw_X.columns)

# %% [markdown]
# ## Feature Selection
# - Autoencoder (in process)
# - PCA

# %%
corr = scaled_X.corr().where(np.tril(np.ones(scaled_X.corr().shape)).astype(np.bool))
f = plt.figure(figsize=(15, 9))
sns.heatmap(corr,cmap='vlag',vmin=-1)
plt.show();

# %%
# PCA

n=5
pca = PCA(n)
pca.fit(scaled_X)
X_pca = pca.transform(scaled_X)

pca_X = pd.DataFrame(X_pca, index=scaled_X.index)
pca_X
# Out:
#                    0         1         2         3         4
# Date
# 2011-06-01  0.108016 -0.478132 -0.270101 -0.040445 -0.207240
# 2011-06-02 -0.004175 -0.515611 -0.326881 -0.008584 -0.210618
# 2011-06-03  0.362016 -0.420713 -0.089656 -0.113797 -0.204675
# 2011-06-06  0.318796 -0.443559 -0.147558 -0.091636 -0.211947
# 2011-06-08  0.263013 -0.466641 -0.167547 -0.106430 -0.204977
# ...              ...       ...       ...       ...       ...
# 2020-12-24 -0.822641  0.821118  0.250106  0.283609 -0.333285
# 2020-12-25 -1.031844  0.847550  0.248742  0.369998 -0.360819
# 2020-12-29 -1.041539  0.881500  0.322476  0.402684 -0.399258
# 2020-12-30 -1.017242  0.881267  0.406267  0.349185 -0.401077
# 2020-12-31 -1.299404  0.859931  0.311670  0.437628 -0.407585
#
# [2271 rows x 5 columns]

# %%
integrated_X = scaled_X.join(pca_X)
corr = integrated_X.corr().where(np.tril(np.ones(integrated_X.corr().shape)).astype(np.bool)).iloc[-n:,:-n].T
f = plt.figure(figsize=(12, 8))
sns.heatmap(corr,cmap='vlag',vmin=-1)
plt.title('PCA correlation with features')
plt.savefig('pcacorr.jpg')
plt.show();

# %% [markdown]
# # Machine Learning

# %%
tmp_data = pca_X.copy()
tmp_data = tmp_data.join(y)
tmp_data.dropna(inplace=True)

X2 = tmp_data.iloc[:,:-1]
y2 = tmp_data.iloc[:,-1]

# %%
t1 = events.t1.loc[X2.index]

# %% [markdown]
# ## Cross Validation (train-test split)

# %% [markdown]
# - Purged K-Fold for Random Forest

# %%
cv = cross_validation.PurgedKFold(n_splits=5,samples_info_sets= t1, pct_embargo = 0.01)

# %% [markdown]
# - For NN

# %%
'''X_train, X_test, y_train, y_test = train_test_split(X2,y2,test_size=0.4,shuffle=False)

X_train = X_train.values.reshape((X_train.shape[0],1, X_train.shape[1]))
X_test = X_test.values.reshape((X_test.shape[0], 1,X_test.shape[1]))'''
# Out:
# 'X_train, X_test, y_train, y_test = train_test_split(X2,y2,test_size=0.4,shuffle=False)\n\nX_train = X_train.values.reshape((X_train.shape[0],1, X_train.shape[1]))\nX_test = X_test.values.reshape((X_test.shape[0], 1,X_test.shape[1]))'

# %% [markdown]
# ## Models

# %%
'''d = 0.2
model = Sequential()
model.add(LSTM(128, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True))
model.add(Dropout(d))
model.add(LSTM(64, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model.add(Dropout(d))
model.add(Dense(16,activation='relu'))        
model.add(Dense(1,activation='relu'))
model.compile(loss='mse',optimizer='adam',metrics=['accuracy'])'''
# Out:
# "d = 0.2\nmodel = Sequential()\nmodel.add(LSTM(128, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True))\nmodel.add(Dropout(d))\nmodel.add(LSTM(64, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))\nmodel.add(Dropout(d))\nmodel.add(Dense(16,activation='relu'))        \nmodel.add(Dense(1,activation='relu'))\nmodel.compile(loss='mse',optimizer='adam',metrics=['accuracy'])"

# %%
#history = model.fit(X_train, y_train, epochs=500, batch_size=500, validation_data=(X_test, y_test), verbose=1, shuffle=False)

# %%
#y_pred_lstm = model.predict(X_test,verbose=1)

# %%
#y_pred_lstm

# %% [markdown]
# - Random Forest Classifier

# %%
rf = RandomForestClassifier(n_estimators=1000,criterion='entropy',max_depth=7)
svc = SVC()

# %% [markdown]
# ## Metrics (Scores)

# %% [markdown]
# ### Random Forest

# %%
y_pred2 = cross_val_predict(rf,X2,y2,cv=cv)

# %%
def crossValPlot(skf,classifier,X,y):
    """Code adapted from:
        
    """
    from itertools import cycle
    from sklearn.metrics import roc_curve, auc
    from scipy import interp
    
    tprs = []
    aucs = []
    mean_fpr = np.linspace(0, 1, 100)
    idx = pd.IndexSlice
    f,ax = plt.subplots(figsize=(10,7))
    i = 0
    for train, test in skf.split(X, y):
        probas_ = (classifier.fit(X.iloc[idx[train]], y.iloc[idx[train]])
                   .predict_proba(X.iloc[idx[test]]))
        # Compute ROC curve and area the curve
        fpr, tpr, thresholds = roc_curve(y.iloc[idx[test]], probas_[:, 1])
        tprs.append(interp(mean_fpr, fpr, tpr))
        tprs[-1][0] = 0.0
        roc_auc = auc(fpr, tpr)
        aucs.append(roc_auc)
        ax.plot(fpr, tpr, lw=1, alpha=0.3,
                 label='ROC fold %d (AUC = %0.2f)' % (i, roc_auc))

        i += 1

    ax.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
             label='Luck', alpha=.8)

    mean_tpr = np.mean(tprs, axis=0)
    mean_tpr[-1] = 1.0
    mean_auc = auc(mean_fpr, mean_tpr)
    std_auc = np.std(aucs)
    ax.plot(mean_fpr, mean_tpr, color='b',
             label=r'Mean ROC (AUC = %0.2f $\pm$ %0.2f)' % (mean_auc, std_auc),
             lw=2, alpha=.8)

    std_tpr = np.std(tprs, axis=0)
    tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
    tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
    ax.fill_between(mean_fpr, tprs_lower, tprs_upper, color='grey', alpha=.2,
                     label=r'$\pm$ 1 std. dev.')

    ax.set_xlim([-0.05, 1.05])
    ax.set_ylim([-0.05, 1.05])
    ax.set_xlabel('False Positive Rate')
    ax.set_ylabel('True Positive Rate')
    ax.set_title('Receiver operating characteristic example')
    ax.legend(bbox_to_anchor=(1,1))
    plt.savefig('cvroc.jpg')
    
crossValPlot(cv,rf,X2,y2)

# %%
cmap = 'gray_r'
plt.figure(figsize=(15,9))
plt.scatter(y2.index, close.loc[y2.index] ,c= y_pred2,cmap=cmap)
cb = plt.colorbar()
cb.ax.tick_params()
plt.title('Bet Prediction(Go or Pass)')
plt.savefig('betpred.jpg')
plt.show()

# %%
print(classification_report(y2, y_pred2))
print("Accuracy = ", accuracy_score(y2, y_pred2))

plt.figure(figsize=(10,6))
mat = confusion_matrix(y2, y_pred2)
sns.heatmap(mat , cmap=plt.cm.Blues, annot=True)
plt.xlabel('predicted label')
plt.ylabel('true label');
plt.title('Confustion Matrix of 2nd Model')
plt.savefig('cm2.jpg')
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.47      0.51       146
#          1.0       0.65      0.72      0.69       199
#
#     accuracy                           0.62       345
#    macro avg       0.60      0.60      0.60       345
# weighted avg       0.61      0.62      0.61       345
#
# Accuracy =  0.6173913043478261

# %% [markdown]
# ## Predicted Probabilities (Confidence of the Bet)

# %%
y_pred_prob = cross_val_predict(rf, X2, y2, cv=cv, method='predict_proba')[:,1]

# %%
p = pd.Series(y_pred_prob)
f=plt.figure(figsize=(15,9))
a = f.gca()
a.hist(p,bins=100)
plt.xlabel('P')
plt.ylabel('Counts')
plt.title('Predicted Probability of Go(bet)')
plt.savefig('Prob.jpg')
plt.show()

# %%
cmap = 'gray_r'

plt.figure(figsize=(15,9))
plt.scatter(y2.index, close.loc[y2.index] ,c= y_pred_prob, cmap=cmap,vmin=0,vmax=1)
cb = plt.colorbar()
cb.ax.tick_params()
plt.title('Bet Probability (Go vs Pass)')
plt.show()

# %% [markdown]
# ## Bet Sizing

# %%
def get_signal(prob, num_classes, side=None):
    if prob.shape[0] == 0:
        return pd.Series(dtype='float64')

    bet_sizes = (prob - 1/num_classes) / (prob * (1 - prob))**0.5

    if not isinstance(side, type(None)):
        bet_sizes = side * (2 * norm.cdf(bet_sizes) - 1)
    else:
        bet_sizes = bet_sizes.apply(lambda s: 2 * norm.cdf(s) - 1)

    return bet_sizes

# %%
def discretize(signal0, step_size):
    signal1 = (signal0 / step_size).round() * step_size
    signal1[signal1 > 1] = 1  # Cap
    signal1[signal1 < -1] = -1  # Floor
    return signal1

# %%
prob = pd.Series(y_pred_prob)
prob.index = y2.index

m = get_signal(prob, 2, side.loc[prob.index])

# %%
m2 = pd.Series(y_pred2,index=y2.index)*side.loc[prob.index]

# %% [markdown]
# Bet size scaling

# %%
mscaler = preprocessing.MinMaxScaler((0,1))
mscaler.fit(m.to_frame())
m_scaled = pd.DataFrame(mscaler.transform(m.to_frame()),columns=['m'],index=y2.index)
m_scaled
# Out:
#                    m
# Date
# 2011-07-11  0.396613
# 2011-09-16  0.744484
# 2011-09-27  0.863786
# 2011-09-29  0.854500
# 2011-10-06  0.850463
# ...              ...
# 2020-12-04  0.036381
# 2020-12-07  0.047485
# 2020-12-09  0.152664
# 2020-12-22  0.185896
# 2020-12-23  0.168057
#
# [345 rows x 1 columns]

# %%
cmap = 'vlag'

plt.figure(figsize=(15,9))
plt.scatter(y2.index, close.loc[y2.index] ,c= m_scaled.m, cmap=cmap,vmin=-1,vmax=1)
cb = plt.colorbar()
cb.ax.tick_params()
plt.title('Bet Size')
plt.savefig('betsize.jpg')
plt.show()

# %%
cmap = 'vlag'

plt.figure(figsize=(15,9))
plt.scatter(y2.index, close.loc[y2.index] ,c= m2, cmap=cmap,vmin=0,vmax=1)
cb = plt.colorbar()
cb.ax.tick_params()
plt.title('Bet')
plt.savefig('betpred.jpg')
plt.show()

# %% [markdown]
# # Trading

# %%
longret = bin.ret*bin.side

# Trend Prediction
firstret = longret*side.loc[y2.index]
cumrfret = firstret.cumsum()

# After Meta-labeling
mlret = longret*m2
cummlret = mlret.cumsum()

# Bet sizing
bsret = longret*m_scaled.m
cumbsret = bsret.cumsum()

# Buy and Hold
buyholdret = (close.loc[y2.index][-1]-close.loc[y2.index][0])/close.loc[y2.index][0]
bh = pd.Series(0, index=y2.index)
bh.iloc[-1] = buyholdret

# %% [markdown]
# # Results

# %% [markdown]
# ## Returns

# %%
dfret = pd.DataFrame({  'Trading Strategy':firstret,
                            'Meta-Label':mlret,
                           'Bet Sizing':bsret,
                     'Buy and Hold':bh})
dfret.describe()
# Out:
#        Trading Strategy  Meta-Label  Bet Sizing  Buy and Hold
# count        345.000000  345.000000  345.000000    345.000000
# mean           0.013625    0.015176    0.009532      0.009483
# std            0.064982    0.052704    0.039349      0.176141
# min           -0.119403   -0.119403   -0.084889      0.000000
# 25%           -0.053700    0.000000   -0.027583      0.000000
# 50%            0.049383    0.000000    0.025016      0.000000
# 75%            0.064865    0.059752    0.040984      0.000000
# max            0.141339    0.141339    0.106216      3.271676

# %%
plotcumret = pd.DataFrame({'Trading Strategy':cumrfret,
                           'Meta-label Bet Strategy':cummlret,
                           'Sized Bet':cumbsret,
                           'Buy and Hold':bh})

plt.figure(figsize=(15,9))
plt.title('Cumulative Returns')
plt.plot(plotcumret)


# Purple line is buy and hold
plt.plot(bh ,color='purple')
plt.legend(plotcumret)
plt.savefig('cumret.jpg')
plt.show()

# %%
def sr(df):
    out = pd.DataFrame(index=['Annualized Sharpe Ratio'])
    for c in df.columns:
        out[c] = (df[c].mean()/df[c].std())*((mt*365)**0.5)
    return out

# %%
df_sr = sr(dfret).style.highlight_max(axis=1)
df_sr
# Out:
# <style  type="text/css" >
# #T_c9b94_row0_col1{
#             background-color:  yellow;
#         }</style><table id="T_c9b94_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Trading Strategy</th>        <th class="col_heading level0 col1" >Meta-Label</th>        <th class="col_heading level0 col2" >Bet Sizing</th>        <th class="col_heading level0 col3" >Buy and Hold</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c9b94_level0_row0" class="row_heading level0 row0" >Annualized Sharpe Ratio</th>
#                         <td id="T_c9b94_row0_col0" class="data row0 col0" >4.005671</td>
#                         <td id="T_c9b94_row0_col1" class="data row0 col1" >5.501108</td>
#                         <td id="T_c9b94_row0_col2" class="data row0 col2" >4.628105</td>
#                         <td id="T_c9b94_row0_col3" class="data row0 col3" >1.028577</td>
#             </tr>
#     </tbody></table>

# %%
import dataframe_image as dfi
dfi.export(df_sr, 'Annualized Sharpe Ratio.png')
